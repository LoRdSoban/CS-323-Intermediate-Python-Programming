# %%
import requests
import json
from PIL import Image, ImageDraw, ImageFont

# %%
r = requests.get('https://api.adviceslip.com/advice')

rand_advice = r.json()

sentence = rand_advice["slip"]["advice"]

img = Image.new('RGB', (1000, 500), color = (255, 255, 255))
d = ImageDraw.Draw(img)

d.text((0,250), sentence, align="center", fill=(100,100,100))

display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x500>
